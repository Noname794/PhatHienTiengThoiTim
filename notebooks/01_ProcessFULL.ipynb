# %%
# Tải các thư viện cần thiết
import os
import sys
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import time

# Thêm đường dẫn src vào hệ thống
sys.path.append(os.path.abspath('../src'))

# Import các module từ src - GIỐNG HỆT FILE GỐC
from preprocessing import preprocess_pipeline
from scattering_features import create_scattering_transform, extract_and_scale_scattering_features
from dataset_loader import find_data_files, get_patient_id_from_path, get_murmur_label, split_and_save_dataset

# CHỈ KHÁC Ở ĐÂY: Import segmentation mới (Hilbert-based) thay vì segmentation_pipeline
from segmentation import segment_cardiac_cycles

# Cài đặt cho plots
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('viridis')
print("Các thư viện và module đã được tải thành công!")
# Out:
# Các thư viện và module đã được tải thành công!

# %%
# 2. Định nghĩa các đường dẫn và tham số
# Đường dẫn đến thư mục dữ liệu
# LƯU Ý: Bạn cần đảm bảo đã tải và giải nén bộ dữ liệu PhysioNet vào thư mục này.
# Cấu trúc dự kiến: ../data/raw/training_data/...
RAW_DATA_DIR = '../data/raw/training_data/' 
PROCESSED_DATA_DIR = '../data/processed/'

# Giả định file metadata có tên là 'training_data.csv' và nằm trong RAW_DATA_DIR
# Đây là file chứa thông tin bệnh nhân và nhãn 'Murmur'
METADATA_FILE = os.path.join(os.path.dirname(RAW_DATA_DIR.rstrip('/')), 'training_data.csv')

# Tham số xử lý - GIỐNG HỆT FILE GỐC
TARGET_SR = 2000
TARGET_CYCLE_LEN = 1600

# Tham số Scattering Transform
J_SCATTER = 2
Q_SCATTER = 8

# Tạo thư mục lưu dữ liệu đã xử lý nếu chưa tồn tại
if not os.path.exists(PROCESSED_DATA_DIR):
    os.makedirs(PROCESSED_DATA_DIR)

print(f"Thư mục dữ liệu thô: {os.path.abspath(RAW_DATA_DIR)}")
print(f"Thư mục lưu dữ liệu xử lý: {os.path.abspath(PROCESSED_DATA_DIR)}")
print(f"File metadata: {os.path.abspath(METADATA_FILE)}")
# Out:
# Thư mục dữ liệu thô: C:\Users\Nguyen duc phat\OneDrive\Máy tính\Heart-Project\data\raw\training_data
# Thư mục lưu dữ liệu xử lý: C:\Users\Nguyen duc phat\OneDrive\Máy tính\Heart-Project\data\processed
# File metadata: C:\Users\Nguyen duc phat\OneDrive\Máy tính\Heart-Project\data\raw\training_data.csv

# %%
# 3. Tải metadata và tìm file dữ liệu
print("Đang tải metadata...")
if os.path.exists(METADATA_FILE):
    metadata_df = pd.read_csv(METADATA_FILE)
    print(f"Đã tải {len(metadata_df)} bản ghi từ file metadata.")
    print(f"Các cột có sẵn: {list(metadata_df.columns)}")
else:
    print(f"Không tìm thấy file metadata: {METADATA_FILE}")
    metadata_df = None

# Tìm các cặp file WAV và TSV
print("\nĐang tìm các file dữ liệu...")
file_pairs = find_data_files(RAW_DATA_DIR)
if file_pairs:
    wav_files, tsv_files = file_pairs
    print(f"Tìm thấy {len(wav_files)} cặp file WAV/TSV để xử lý.")
else:
    print("Không tìm thấy file dữ liệu nào!")
    wav_files, tsv_files = [], []
# Out:
# Đang tải metadata...
# Đã tải 942 bản ghi từ file metadata.
# Các cột có sẵn: ['Patient ID', 'Recording locations:', 'Age', 'Sex', 'Height', 'Weight', 'Pregnancy status', 'Murmur', 'Murmur locations', 'Most audible location', 'Systolic murmur timing', 'Systolic murmur shape', 'Systolic murmur grading', 'Systolic murmur pitch', 'Systolic murmur quality', 'Diastolic murmur timing', 'Diastolic murmur shape', 'Diastolic murmur grading', 'Diastolic murmur pitch', 'Diastolic murmur quality', 'Outcome', 'Campaign', 'Additional ID']
#
# Đang tìm các file dữ liệu...
# Tìm thấy 3163 cặp file WAV/TSV để xử lý.

# %%
# ===== GIAI ĐOẠN 1: THU THẬP CHU KỲ THÔ =====
import librosa
import random

# Danh sách lưu tất cả chu kỳ thô và thông tin liên quan
all_raw_cycles_info = []
initial_durations_flat = []
error_count = 0
processed_files_count = 0

print(f"Bắt đầu xử lý {len(wav_files)} file WAV để thu thập chu kỳ tim...")

# Thu thập chu kỳ từ tất cả các file
for wav_path, tsv_path in tqdm(zip(wav_files, tsv_files), total=len(wav_files), desc="Đang xử lý các file"):
    try:
        # 1. Tải tín hiệu âm thanh
        signal, sr = librosa.load(wav_path, sr=TARGET_SR)
        
        # 2. Tiền xử lý tín hiệu
        signal_processed = preprocess_pipeline(signal, sr)
        
        # 3. Lấy patient ID và nhãn
        patient_id = get_patient_id_from_path(wav_path)
        murmur_label = get_murmur_label(patient_id, metadata_df) if metadata_df is not None else None
        
        if murmur_label is None:
            continue
            
        # 4. KHÁC BIỆT: Sử dụng Hilbert Transform thay vì segmentation_pipeline
        cardiac_cycles = segment_cardiac_cycles(signal_processed, sr)
        
        if cardiac_cycles:
            # Thu thập tất cả chu kỳ từ file này
            for cycle in cardiac_cycles:
                all_raw_cycles_info.append({
                    'cycle': cycle,
                    'patient_id': patient_id,
                    'label': murmur_label,
                    'file_path': wav_path
                })
                initial_durations_flat.append(len(cycle))
            
        processed_files_count += 1
            
    except Exception as e:
        print(f"Lỗi khi xử lý {os.path.basename(wav_path)}: {e}")
        error_count += 1

print(f"\nHoàn tất thu thập chu kỳ thô:")
print(f"- Đã xử lý thành công: {processed_files_count} file")
print(f"- Lỗi: {error_count} file")
print(f"- Tổng số chu kỳ thu thập được: {len(all_raw_cycles_info)}")
if initial_durations_flat:
    print(f"- Độ dài chu kỳ trung bình: {np.mean(initial_durations_flat):.2f} samples")
    print(f"- Phạm vi độ dài: {min(initial_durations_flat)} - {max(initial_durations_flat)} samples")
# Out:
# Bắt đầu xử lý 3163 file WAV để thu thập chu kỳ tim...
# Đang xử lý các file:   0%|          | 0/3163 [00:00<?, ?it/s]
# C:\Users\Nguyen duc phat\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 20576 samples
# Đã tính Hilbert envelope cho 20576 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8391
# Tìm thấy 20 peaks.
# Vị trí S1 (samples): [  623  1764  2905  4064  5220  6332  7502  8668  9820 10957]...
# Đã tách được 19 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 57568 samples
# Đã tính Hilbert envelope cho 57568 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0045
# Tìm thấy 27 peaks.
# Vị trí S1 (samples): [ 1259  4723  8357 10442 12770 13929 15092 16248 19706 22037]...
# Đã tách được 26 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 18784 samples
# Đã tính Hilbert envelope cho 18784 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8822
# Tìm thấy 17 peaks.
# Vị trí S1 (samples): [  798  1928  3054  4192  5337  6455  7590  8728  9847 10978]...
# Đã tách được 16 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 13184 samples
# Đã tính Hilbert envelope cho 13184 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.5543
# Tìm thấy 19 peaks.
# Vị trí S1 (samples): [ 825 1440 1950 2576 3081 3699 4213 4828 5329 5953]...
# Đã tách được 18 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 40960 samples
# Đã tính Hilbert envelope cho 40960 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0181
# Tìm thấy 15 peaks.
# Vị trí S1 (samples): [ 3507  4382 16862 22172 26048 28099 29127 29751 31193 33240]...
# Đã tách được 14 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 40096 samples
# Đã tính Hilbert envelope cho 40096 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8824
# Tìm thấy 8 peaks.
# Vị trí S1 (samples): [ 3009  3867  7130  7918 22485 31698 33929 39968]...
# Đã tách được 7 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 42592 samples
# Đã tính Hilbert envelope cho 42592 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9874
# Tìm thấy 46 peaks.
# Vị trí S1 (samples): [ 226  897 2472 3491 4031 5051 5512 6026 7442 7924]...
# Đã tách được 45 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 65696 samples
# Đã tính Hilbert envelope cho 65696 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9368
# Tìm thấy 11 peaks.
# Vị trí S1 (samples): [   59   531  5438  6039  6543  8718  9062  9782 64264 64601]...
# Đã tách được 10 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 44096 samples
# Đã tính Hilbert envelope cho 44096 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1191
# Tìm thấy 23 peaks.
# Vị trí S1 (samples): [ 2096  4641  7596 10333 12537 15473 18386 24670 27010 27490]...
# Đã tách được 22 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 45568 samples
# Đã tính Hilbert envelope cho 45568 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9880
# Tìm thấy 57 peaks.
# Vị trí S1 (samples): [ 446  931 1515 1994 2636 3767 4251 4863 5351 5932]...
# Đã tách được 56 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 41184 samples
# Đã tính Hilbert envelope cho 41184 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1367
# Tìm thấy 49 peaks.
# Vị trí S1 (samples): [ 1168  2271  3809  4477  6041  6672  8860 12210 14363 15399]...
# Đã tách được 48 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 54368 samples
# Đã tính Hilbert envelope cho 54368 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1389
# Tìm thấy 53 peaks.
# Vị trí S1 (samples): [  46  632 1658 2680 3748 4807 5829 6867 7900 8353]...
# Đã tách được 52 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 40928 samples
# Đã tính Hilbert envelope cho 40928 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9009
# Tìm thấy 41 peaks.
# Vị trí S1 (samples): [ 1078  3093  4157  5253  6341  7363  8346  9340 10412 11492]...
# Đã tách được 40 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 42560 samples
# Đã tính Hilbert envelope cho 42560 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.6053
# Tìm thấy 63 peaks.
# Vị trí S1 (samples): [ 438 1422 2468 3506 4074 4535 5051 5534 6018 6503]...
# Đã tách được 62 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 61280 samples
# Đã tính Hilbert envelope cho 61280 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8810
# Tìm thấy 58 peaks.
# Vị trí S1 (samples): [  511  1563  2566  3517  4508  5546  6534  7467  8395 11130]...
# Đã tách được 57 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 40992 samples
# Đã tính Hilbert envelope cho 40992 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.7817
# Tìm thấy 65 peaks.
# Vị trí S1 (samples): [ 435 1505 2114 2580 3151 3613 4622 5142 5607 6645]...
# Đã tách được 64 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 25792 samples
# Đã tính Hilbert envelope cho 25792 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8756
# Tìm thấy 20 peaks.
# Vị trí S1 (samples): [  759  1851  5610  6664  8752  9754 10837 12889 13836 14920]...
# Đã tách được 19 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 45184 samples
# Đã tính Hilbert envelope cho 45184 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.7255
# Tìm thấy 45 peaks.
# Vị trí S1 (samples): [ 217  707 1427 2423 3050 3421 4361 5296 7256 8183]...
# Đã tách được 44 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 23360 samples
# Đã tính Hilbert envelope cho 23360 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.7643
# Tìm thấy 26 peaks.
# Vị trí S1 (samples): [ 466 1471 1974 2459 3478 4420 4862 5358 6340 7280]...
# Đã tách được 25 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 28192 samples
# Đã tính Hilbert envelope cho 28192 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9753
# Tìm thấy 18 peaks.
# Vị trí S1 (samples): [  144  4039  6028  6973 10099 11075 15034 16058 17068 18039]...
# Đã tách được 17 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 47200 samples
# Đã tính Hilbert envelope cho 47200 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9567
# Tìm thấy 11 peaks.
# Vị trí S1 (samples): [25467 27453 28517 28934 29633 34129 38022 42737 43236 44221]...
# Đã tách được 10 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 53376 samples
# Đã tính Hilbert envelope cho 53376 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.6081
# Tìm thấy 67 peaks.
# Vị trí S1 (samples): [  130  1263  2631  3985  5386  6746  8128  9336 10427 11491]...
# Đã tách được 66 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 26112 samples
# Đã tính Hilbert envelope cho 26112 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9657
# Tìm thấy 33 peaks.
# Vị trí S1 (samples): [  48  695 1196 2327 2741 3413 4477 5563 6661 7281]...
# Đã tách được 32 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 29984 samples
# Đã tính Hilbert envelope cho 29984 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.7859
# Tìm thấy 33 peaks.
# Vị trí S1 (samples): [ 521 1543 2576 3593 4633 5693 6747 7294 7733 8737]...
# Đã tách được 32 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 45792 samples
# Đã tính Hilbert envelope cho 45792 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9094
# Tìm thấy 58 peaks.
# Vị trí S1 (samples): [ 519  936 1509 1943 2490 2905 3843 5296 5738 6275]...
# Đã tách được 57 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 40992 samples
# Đã tính Hilbert envelope cho 40992 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8314
# Tìm thấy 45 peaks.
# Vị trí S1 (samples): [  146  1145  4561  5518  6913  9290  9767 10230 11159 11620]...
# Đã tách được 44 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 42592 samples
# Đã tính Hilbert envelope cho 42592 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9537
# Tìm thấy 85 peaks.
# Vị trí S1 (samples): [ 339  834 1285 1811 2259 2807 3248 4219 4720 5177]...
# Đã tách được 84 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 45504 samples
# Đã tính Hilbert envelope cho 45504 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0036
# Tìm thấy 71 peaks.
# Vị trí S1 (samples): [ 363 1333 2308 3287 4244 5182 5682 6136 6639 7078]...
# Đã tách được 70 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 17792 samples
# Đã tính Hilbert envelope cho 17792 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0322
# Tìm thấy 18 peaks.
# Vị trí S1 (samples): [1082 2117 3173 4235 5316 6359 6940 7409 8454 9474]...
# Đã tách được 17 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 29600 samples
# Đã tính Hilbert envelope cho 29600 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.7510
# Tìm thấy 10 peaks.
# Vị trí S1 (samples): [ 1290  2710  4356  9391  9697 12381 17776 18456 20532 29471]...
# Đã tách được 9 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 29888 samples
# Đã tính Hilbert envelope cho 29888 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.7735
# Tìm thấy 34 peaks.
# Vị trí S1 (samples): [1063 2084 3143 4204 5228 5741 6292 7293 8321 8877]...
# Đã tách được 33 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 26784 samples
# Đã tính Hilbert envelope cho 26784 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.7105
# Tìm thấy 27 peaks.
# Vị trí S1 (samples): [  115  1174  2217  4304  5305  6297  8575  9204 10187 11145]...
# Đã tách được 26 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 23488 samples
# Đã tính Hilbert envelope cho 23488 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8958
# Tìm thấy 26 peaks.
# Vị trí S1 (samples): [ 326 1872 2897 3437 4380 4920 6457 8024 8953 9481]...
# Đã tách được 25 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 30560 samples
# Đã tính Hilbert envelope cho 30560 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9231
# Tìm thấy 29 peaks.
# Vị trí S1 (samples): [  852  2352  3883  5406  6861  8305  9758 11169 12495 13004]...
# Đã tách được 28 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 39584 samples
# Đã tính Hilbert envelope cho 39584 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1072
# Tìm thấy 32 peaks.
# Vị trí S1 (samples): [ 1414  2425  2921  4357  5892  7452  8866 10247 11710 13221]...
# Đã tách được 31 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 36320 samples
# Đã tính Hilbert envelope cho 36320 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.2146
# Tìm thấy 36 peaks.
# Vị trí S1 (samples): [ 1428  2839  4266  5727  6246  7095  7603  8513 10000 11547]...
# Đã tách được 35 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 39808 samples
# Đã tính Hilbert envelope cho 39808 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1625
# Tìm thấy 44 peaks.
# Vị trí S1 (samples): [ 261 1114 1681 2603 3168 4240 4790 6441 7918 9396]...
# Đã tách được 43 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 41984 samples
# Đã tính Hilbert envelope cho 41984 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8059
# Tìm thấy 7 peaks.
# Vị trí S1 (samples): [  508  9438 12233 20168 27328 28658 41851]...
# Đã tách được 6 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 40512 samples
# Đã tính Hilbert envelope cho 40512 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0256
# Tìm thấy 41 peaks.
# Vị trí S1 (samples): [ 1600  2900  3855  4348  5920  7567  8530  9990 13199 13753]...
# Đã tách được 40 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 39392 samples
# Đã tính Hilbert envelope cho 39392 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9477
# Tìm thấy 26 peaks.
# Vị trí S1 (samples): [   48  1611  2150  3098  4572  6050  7636  9292 10817 12364]...
# Đã tách được 25 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 28992 samples
# Đã tính Hilbert envelope cho 28992 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9983
# Tìm thấy 23 peaks.
# Vị trí S1 (samples): [  766  1544  3631  5526  5950  6877  8974 11715 12645 16921]...
# Đã tách được 22 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 37376 samples
# Đã tính Hilbert envelope cho 37376 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9997
# Tìm thấy 28 peaks.
# Vị trí S1 (samples): [ 3126  7592 13419 15545 17412 18365 19382 20296 20691 22979]...
# Đã tách được 27 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 24384 samples
# Đã tính Hilbert envelope cho 24384 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1528
# Tìm thấy 21 peaks.
# Vị trí S1 (samples): [ 1158  2129  2722  3456  4039  4803  5406  7013  9505 10041]...
# Đã tách được 20 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 47360 samples
# Đã tính Hilbert envelope cho 47360 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.7702
# Tìm thấy 43 peaks.
# Vị trí S1 (samples): [  503  1912  3225  4673  5682  7043  8552  9854 11166 12558]...
# Đã tách được 42 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 25792 samples
# Đã tính Hilbert envelope cho 25792 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9575
# Tìm thấy 21 peaks.
# Vị trí S1 (samples): [ 2067  3327  4905  6497  8725  9365 10749 12348 12961 16478]...
# Đã tách được 20 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 22592 samples
# Đã tính Hilbert envelope cho 22592 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8613
# Tìm thấy 27 peaks.
# Vị trí S1 (samples): [1631 2418 3017 3630 4193 5353 6091 7264 8502 9080]...
# Đã tách được 26 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 22592 samples
# Đã tính Hilbert envelope cho 22592 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9580
# Tìm thấy 14 peaks.
# Vị trí S1 (samples): [  236   869  1427  2882  4143  4981  5431 14800 15951 16375]...
# Đã tách được 13 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 38176 samples
# Đã tính Hilbert envelope cho 38176 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1144
# Tìm thấy 25 peaks.
# Vị trí S1 (samples): [ 4765 17813 18450 19053 21033 22096 23150 24254 26165 29195]...
# Đã tách được 24 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 36384 samples
# Đã tính Hilbert envelope cho 36384 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.3500
# Tìm thấy 6 peaks.
# Vị trí S1 (samples): [ 1459  3493  4457 12545 20204 33502]...
# Đã tách được 5 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 21984 samples
# Đã tính Hilbert envelope cho 21984 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.3902
# Tìm thấy 4 peaks.
# Vị trí S1 (samples): [   85  8622 19423 21041]...
# Đã tách được 3 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 23776 samples
# Đã tính Hilbert envelope cho 23776 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0134
# Tìm thấy 8 peaks.
# Vị trí S1 (samples): [ 1674  3404  8653 12961 14101 16406 22533 23636]...
# Đã tách được 7 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 64384 samples
# Đã tính Hilbert envelope cho 64384 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9391
# Tìm thấy 36 peaks.
# Vị trí S1 (samples): [ 2458  2898  4163  4972  6425  7591  8826 10106 11264 12454]...
# Đã tách được 35 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 26784 samples
# Đã tính Hilbert envelope cho 26784 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0929
# Tìm thấy 27 peaks.
# Vị trí S1 (samples): [ 758 1227 1565 2077 3304 4635 6010 6910 7445 8310]...
# Đã tách được 26 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 38304 samples
# Đã tính Hilbert envelope cho 38304 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9215
# Tìm thấy 44 peaks.
# Vị trí S1 (samples): [ 755 1283 1989 4560 5766 6280 6923 7446 8133 8649]...
# Đã tách được 43 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 42368 samples
# Đã tính Hilbert envelope cho 42368 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0566
# Tìm thấy 8 peaks.
# Vị trí S1 (samples): [   42  1295  3574 11322 11662 12780 14617 42128]...
# Đã tách được 7 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 40960 samples
# Đã tính Hilbert envelope cho 40960 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9474
# Tìm thấy 15 peaks.
# Vị trí S1 (samples): [  172  1288  6103  6534  7096  8168  8503 11927 34541 36824]...
# Đã tách được 14 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 43488 samples
# Đã tính Hilbert envelope cho 43488 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8510
# Tìm thấy 34 peaks.
# Vị trí S1 (samples): [ 240  656 1158 1710 2776 3367 3874 4955 6574 7279]...
# Đã tách được 33 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 59104 samples
# Đã tính Hilbert envelope cho 59104 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0903
# Tìm thấy 53 peaks.
# Vị trí S1 (samples): [ 154 1403 1870 2508 3649 4878 6071 7215 8381 9221]...
# Đã tách được 52 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 40704 samples
# Đã tính Hilbert envelope cho 40704 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0349
# Tìm thấy 34 peaks.
# Vị trí S1 (samples): [ 1559  2423  3860  5312  5870  7342 10317 11184 13224 14730]...
# Đã tách được 33 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 41504 samples
# Đã tính Hilbert envelope cho 41504 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0724
# Tìm thấy 31 peaks.
# Vị trí S1 (samples): [  924  2500  4071  5531  7032  8533 10032 11426 12901 14386]...
# Đã tách được 30 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 43584 samples
# Đã tính Hilbert envelope cho 43584 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1570
# Tìm thấy 26 peaks.
# Vị trí S1 (samples): [ 3263  4877  6309  7805  9443 11056 12197 14127 15559 17136]...
# Đã tách được 25 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 40160 samples
# Đã tính Hilbert envelope cho 40160 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0362
# Tìm thấy 41 peaks.
# Vị trí S1 (samples): [ 580 1542 2103 3124 3668 4693 5236 6249 6812 7767]...
# Đã tách được 40 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 41504 samples
# Đã tính Hilbert envelope cho 41504 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1059
# Tìm thấy 25 peaks.
# Vị trí S1 (samples): [ 3489  4206  5677  6418  7167  7894  9379 10128 10614 11644]...
# Đã tách được 24 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 41024 samples
# Đã tính Hilbert envelope cho 41024 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0010
# Tìm thấy 28 peaks.
# Vị trí S1 (samples): [  137  1173  3821  5795  7126  7855  8664  9043 10144 10904]...
# Đã tách được 27 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 37568 samples
# Đã tính Hilbert envelope cho 37568 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8937
# Tìm thấy 66 peaks.
# Vị trí S1 (samples): [2313 3853 5421 6197 6567 6990 7333 7753 8127 8551]...
# Đã tách được 65 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 43776 samples
# Đã tính Hilbert envelope cho 43776 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9537
# Tìm thấy 45 peaks.
# Vị trí S1 (samples): [ 285  697 1089 1859 2655 3448 4244 4688 5048 5850]...
# Đã tách được 44 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 42176 samples
# Đã tính Hilbert envelope cho 42176 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1255
# Tìm thấy 30 peaks.
# Vị trí S1 (samples): [ 503  996 1874 2360 3257 3737 4354 6477 7825 8698]...
# Đã tách được 29 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 42976 samples
# Đã tính Hilbert envelope cho 42976 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0829
# Tìm thấy 49 peaks.
# Vị trí S1 (samples): [ 612 1372 1868 2561 3100 3796 4306 5022 5562 6272]...
# Đã tách được 48 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 41984 samples
# Đã tính Hilbert envelope cho 41984 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1126
# Tìm thấy 50 peaks.
# Vị trí S1 (samples): [ 144 1349 2099 2591 3028 3396 3889 4678 5235 6451]...
# Đã tách được 49 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 43392 samples
# Đã tính Hilbert envelope cho 43392 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9403
# Tìm thấy 18 peaks.
# Vị trí S1 (samples): [  516  1214  1740  2460  2971  3678  4418  7405 10341 10799]...
# Đã tách được 17 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 43776 samples
# Đã tính Hilbert envelope cho 43776 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8358
# Tìm thấy 31 peaks.
# Vị trí S1 (samples): [  770  1830  4354  5009  5436  6113  7193  9560 10187 10616]...
# Đã tách được 30 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 40608 samples
# Đã tính Hilbert envelope cho 40608 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1510
# Tìm thấy 41 peaks.
# Vị trí S1 (samples): [ 810 1745 2710 3719 4715 5672 6650 7665 8694 9651]...
# Đã tách được 40 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 41184 samples
# Đã tính Hilbert envelope cho 41184 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0842
# Tìm thấy 19 peaks.
# Vị trí S1 (samples): [  143  5261  6272  8246 10143 11134 16952 17983 19892 21784]...
# Đã tách được 18 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 40704 samples
# Đã tính Hilbert envelope cho 40704 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.2051
# Tìm thấy 40 peaks.
# Vị trí S1 (samples): [ 798 1931 2954 3943 4953 6013 7059 8023 8971 9935]...
# Đã tách được 39 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 31488 samples
# Đã tính Hilbert envelope cho 31488 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0870
# Tìm thấy 25 peaks.
# Vị trí S1 (samples): [ 1174  2408  6061  6572  7305  9302 10214 10869 11422 12092]...
# Đã tách được 24 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 38592 samples
# Đã tính Hilbert envelope cho 38592 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8099
# Tìm thấy 31 peaks.
# Vị trí S1 (samples): [  982  3727  4953  6103  6673  7230  7829  8394 10824 11936]...
# Đã tách được 30 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 29376 samples
# Đã tính Hilbert envelope cho 29376 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0728
# Tìm thấy 29 peaks.
# Vị trí S1 (samples): [  961  2032  2614  3145  5417  6529  7189  7717  8480 12320]...
# Đã tách được 28 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 25504 samples
# Đã tính Hilbert envelope cho 25504 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1068
# Tìm thấy 31 peaks.
# Vị trí S1 (samples): [ 152  888 2073 3212 4302 5460 6659 7871 8938 9471]...
# Đã tách được 30 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 40992 samples
# Đã tính Hilbert envelope cho 40992 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1555
# Tìm thấy 25 peaks.
# Vị trí S1 (samples): [3239 3582 4317 6131 6475 6872 8084 8517 9307 9619]...
# Đã tách được 24 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 39104 samples
# Đã tính Hilbert envelope cho 39104 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.4576
# Tìm thấy 3 peaks.
# Vị trí S1 (samples): [19660 22575 38236]...
# Đã tách được 2 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 42784 samples
# Đã tính Hilbert envelope cho 42784 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0414
# Tìm thấy 23 peaks.
# Vị trí S1 (samples): [ 3831  5043  9815 10719 11921 12246 13647 14393 14736 15157]...
# Đã tách được 22 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 42784 samples
# Đã tính Hilbert envelope cho 42784 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0702
# Tìm thấy 56 peaks.
# Vị trí S1 (samples): [1253 1958 2327 2686 3430 4156 4907 5665 6407 7162]...
# Đã tách được 55 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 31488 samples
# Đã tính Hilbert envelope cho 31488 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1860
# Tìm thấy 39 peaks.
# Vị trí S1 (samples): [ 117  913 1724 2516 3303 4099 4885 5656 6442 7199]...
# Đã tách được 38 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 18176 samples
# Đã tính Hilbert envelope cho 18176 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.7089
# Tìm thấy 7 peaks.
# Vị trí S1 (samples): [ 4414  8004 15844 16858 17181 17668 18114]...
# Đã tách được 6 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 41600 samples
# Đã tính Hilbert envelope cho 41600 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0295
# Tìm thấy 15 peaks.
# Vị trí S1 (samples): [ 1946  2282  3034  3526  4020  4528 19030 24570 30114 34223]...
# Đã tách được 14 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 58784 samples
# Đã tính Hilbert envelope cho 58784 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8605
# Tìm thấy 115 peaks.
# Vị trí S1 (samples): [ 4794  5293  5659  6145  6549  7991  8919  9390  9851 10282]...
# Đã tách được 114 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 60704 samples
# Đã tính Hilbert envelope cho 60704 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9625
# Tìm thấy 11 peaks.
# Vị trí S1 (samples): [  246  1430  2024  3517  7132  7860  8290  9282 11436 60215]...
# Đã tách được 10 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 64704 samples
# Đã tính Hilbert envelope cho 64704 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.7526
# Tìm thấy 43 peaks.
# Vị trí S1 (samples): [ 132  656 1262 2207 2790 3511 5393 6281 7237 7833]...
# Đã tách được 42 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 59584 samples
# Đã tính Hilbert envelope cho 59584 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0421
# Tìm thấy 71 peaks.
# Vị trí S1 (samples): [ 198 1061 2135 2781 4104 4793 5691 6343 7651 8288]...
# Đã tách được 70 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 60800 samples
# Đã tính Hilbert envelope cho 60800 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1857
# Tìm thấy 68 peaks.
# Vị trí S1 (samples): [ 145  830 2156 2763 3885 4469 5189 5810 6809 7434]...
# Đã tách được 67 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 58784 samples
# Đã tính Hilbert envelope cho 58784 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1619
# Tìm thấy 64 peaks.
# Vị trí S1 (samples): [  397  2315  2855  3569  5448  6081  6611  9148  9791 10990]...
# Đã tách được 63 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 58976 samples
# Đã tính Hilbert envelope cho 58976 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9901
# Tìm thấy 71 peaks.
# Vị trí S1 (samples): [ 167  873 2171 2734 3425 3947 4594 5770 6334 6922]...
# Đã tách được 70 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 58784 samples
# Đã tính Hilbert envelope cho 58784 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0112
# Tìm thấy 81 peaks.
# Vị trí S1 (samples): [ 155 1038 1617 2371 2900 3534 4075 4774 5325 6574]...
# Đã tách được 80 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 58304 samples
# Đã tính Hilbert envelope cho 58304 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.3988
# Tìm thấy 10 peaks.
# Vị trí S1 (samples): [17402 19747 36934 40767 41510 42966 52633 53669 54078 58151]...
# Đã tách được 9 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 53984 samples
# Đã tính Hilbert envelope cho 53984 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0825
# Tìm thấy 5 peaks.
# Vị trí S1 (samples): [ 6916 12749 13089 53080 53892]...
# Đã tách được 4 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 61696 samples
# Đã tính Hilbert envelope cho 61696 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.6242
# Tìm thấy 25 peaks.
# Vị trí S1 (samples): [  125   484  1528  2140  3766  6616  8240 13927 14574 15502]...
# Đã tách được 24 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 56896 samples
# Đã tính Hilbert envelope cho 56896 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0120
# Tìm thấy 62 peaks.
# Vị trí S1 (samples): [  58 1314 1835 2253 3146 4464 5178 5747 8195 8743]...
# Đã tách được 61 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 65504 samples
# Đã tính Hilbert envelope cho 65504 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.7036
# Tìm thấy 48 peaks.
# Vị trí S1 (samples): [ 233  671 1969 3417 3781 4322 4844 5630 6170 7599]...
# Đã tách được 47 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 59904 samples
# Đã tính Hilbert envelope cho 59904 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0937
# Tìm thấy 46 peaks.
# Vị trí S1 (samples): [ 1464  3462  4465  6417  7349  7860  8335  9325 11244 12184]...
# Đã tách được 45 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 56608 samples
# Đã tính Hilbert envelope cho 56608 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0607
# Tìm thấy 105 peaks.
# Vị trí S1 (samples): [ 493 1012 2515 3928 4416 4909 5398 5893 6381 6886]...
# Đã tách được 104 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 54496 samples
# Đã tính Hilbert envelope cho 54496 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8842
# Tìm thấy 49 peaks.
# Vị trí S1 (samples): [ 1205  5286  5746  7310  9511 10536 11033 12645 14749 15229]...
# Đã tách được 48 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 31904 samples
# Đã tính Hilbert envelope cho 31904 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9759
# Tìm thấy 26 peaks.
# Vị trí S1 (samples): [ 298 1421 2499 3575 4669 5787 6916 7994 8504 9043]...
# Đã tách được 25 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 47776 samples
# Đã tính Hilbert envelope cho 47776 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1253
# Tìm thấy 15 peaks.
# Vị trí S1 (samples): [   72   500  1828  2779 21552 26946 32214 33314 37433 38590]...
# Đã tách được 14 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 30592 samples
# Đã tính Hilbert envelope cho 30592 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0792
# Tìm thấy 47 peaks.
# Vị trí S1 (samples): [1257 2283 3316 4412 5542 6619 7193 8235 8755 9285]...
# Đã tách được 46 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 47808 samples
# Đã tính Hilbert envelope cho 47808 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0588
# Tìm thấy 65 peaks.
# Vị trí S1 (samples): [  60  559 1124 1644 2272 2776 3355 3882 4496 4998]...
# Đã tách được 64 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 62112 samples
# Đã tính Hilbert envelope cho 62112 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.6183
# Tìm thấy 9 peaks.
# Vị trí S1 (samples): [  141 25105 30634 33541 39897 46841 55155 60955 61986]...
# Đã tách được 8 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 69184 samples
# Đã tính Hilbert envelope cho 69184 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.7488
# Tìm thấy 11 peaks.
# Vị trí S1 (samples): [  199  1119 10061 12173 32456 33233 34302 67380 67693 68575]...
# Đã tách được 10 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 60192 samples
# Đã tính Hilbert envelope cho 60192 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0094
# Tìm thấy 67 peaks.
# Vị trí S1 (samples): [ 259 1045 1500 2147 3184 4247 5397 6575 7667 8781]...
# Đã tách được 66 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 75904 samples
# Đã tính Hilbert envelope cho 75904 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.6607
# Tìm thấy 16 peaks.
# Vị trí S1 (samples): [  415  3408  5308 13177 20595 25560 29057 30220 30627 36686]...
# Đã tách được 15 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 57920 samples
# Đã tính Hilbert envelope cho 57920 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.7508
# Tìm thấy 44 peaks.
# Vị trí S1 (samples): [  256   563  2655  4020  4847  5280  5847  7005  9678 11426]...
# Đã tách được 43 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 62112 samples
# Đã tính Hilbert envelope cho 62112 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8272
# Tìm thấy 59 peaks.
# Vị trí S1 (samples): [ 311 1222 1656 2344 2903 4052 4661 5242 6224 6566]...
# Đã tách được 58 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 58688 samples
# Đã tính Hilbert envelope cho 58688 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0074
# Tìm thấy 60 peaks.
# Vị trí S1 (samples): [   94  1233  2884  4301  5603  6983  8332  9616 10781 11969]...
# Đã tách được 59 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 59584 samples
# Đã tính Hilbert envelope cho 59584 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0422
# Tìm thấy 73 peaks.
# Vị trí S1 (samples): [ 271  894 1433 2123 2656 3302 3856 4472 5010 5619]...
# Đã tách được 72 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 67488 samples
# Đã tính Hilbert envelope cho 67488 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.3084
# Tìm thấy 28 peaks.
# Vị trí S1 (samples): [  358 11001 13768 16521 20596 29926 31212 32377 33895 36358]...
# Đã tách được 27 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 62592 samples
# Đã tính Hilbert envelope cho 62592 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0797
# Tìm thấy 17 peaks.
# Vị trí S1 (samples): [  265  5065  5832 22288 24370 24893 25225 30686 50649 51016]...
# Đã tách được 16 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 58176 samples
# Đã tính Hilbert envelope cho 58176 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0724
# Tìm thấy 70 peaks.
# Vị trí S1 (samples): [  44  447  964 1434 2101 2573 4401 4868 5508 5979]...
# Đã tách được 69 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 66368 samples
# Đã tính Hilbert envelope cho 66368 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8214
# Tìm thấy 87 peaks.
# Vị trí S1 (samples): [3648 4280 4759 5348 5821 6366 6836 7394 7878 8414]...
# Đã tách được 86 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 70720 samples
# Đã tính Hilbert envelope cho 70720 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1155
# Tìm thấy 25 peaks.
# Vị trí S1 (samples): [   54  1079  2139  6116  6558 11608 12212 15278 23394 31050]...
# Đã tách được 24 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 62304 samples
# Đã tính Hilbert envelope cho 62304 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0422
# Tìm thấy 71 peaks.
# Vị trí S1 (samples): [ 177  848 2148 2780 3360 4011 4619 5486 7120 8818]...
# Đã tách được 70 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 60384 samples
# Đã tính Hilbert envelope cho 60384 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0260
# Tìm thấy 89 peaks.
# Vị trí S1 (samples): [ 750 1319 2008 2562 3601 4174 5012 5590 6841 7424]...
# Đã tách được 88 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 59104 samples
# Đã tính Hilbert envelope cho 59104 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1777
# Tìm thấy 69 peaks.
# Vị trí S1 (samples): [ 414 1258 2639 3821 4351 5034 5603 6388 6953 7712]...
# Đã tách được 68 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 61984 samples
# Đã tính Hilbert envelope cho 61984 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9153
# Tìm thấy 58 peaks.
# Vị trí S1 (samples): [   67  1195  6899  7505  9736 11885 17406 18523 20631 31036]...
# Đã tách được 57 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 60320 samples
# Đã tính Hilbert envelope cho 60320 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0961
# Tìm thấy 65 peaks.
# Vị trí S1 (samples): [ 113  530 1863 2366 2817 3756 4778 5763 6784 7818]...
# Đã tách được 64 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 59488 samples
# Đã tính Hilbert envelope cho 59488 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1241
# Tìm thấy 32 peaks.
# Vị trí S1 (samples): [  104   771  1901  2285  6102  7843 11692 12977 14436 17831]...
# Đã tách được 31 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 61984 samples
# Đã tính Hilbert envelope cho 61984 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.2583
# Tìm thấy 43 peaks.
# Vị trí S1 (samples): [  215  2423  8377 11460 13794 14916 16027 17281 19366 22699]...
# Đã tách được 42 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 62720 samples
# Đã tính Hilbert envelope cho 62720 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.2119
# Tìm thấy 40 peaks.
# Vị trí S1 (samples): [  252  2146  5139  6465  7982  9514 12982 14100 15393 17006]...
# Đã tách được 39 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 63680 samples
# Đã tính Hilbert envelope cho 63680 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.2254
# Tìm thấy 43 peaks.
# Vị trí S1 (samples): [  390  1028  2015  3582  5194  6658  7795  8867 10032 11368]...
# Đã tách được 42 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 63296 samples
# Đã tính Hilbert envelope cho 63296 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1284
# Tìm thấy 43 peaks.
# Vị trí S1 (samples): [ 318  970 1625 1928 2890 3266 3874 4851 5840 6863]...
# Đã tách được 42 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 61792 samples
# Đã tính Hilbert envelope cho 61792 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.2340
# Tìm thấy 50 peaks.
# Vị trí S1 (samples): [ 230 1153 1841 2922 4004 5096 6177 7251 8324 8868]...
# Đã tách được 49 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 59104 samples
# Đã tính Hilbert envelope cho 59104 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.2438
# Tìm thấy 61 peaks.
# Vị trí S1 (samples): [  667  1754  2825  3863  4969  6054  7159  8254  9306 10391]...
# Đã tách được 60 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 60800 samples
# Đã tính Hilbert envelope cho 60800 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1800
# Tìm thấy 79 peaks.
# Vị trí S1 (samples): [  401  2746  5547  6638 10027 11119 12228 13324 14405 15518]...
# Đã tách được 78 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 58304 samples
# Đã tính Hilbert envelope cho 58304 samples
# ...
# Đã tính Hilbert envelope cho 42976 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.6731
# Tìm thấy 46 peaks.
# Vị trí S1 (samples): [  50 1035 2001 2983 3908 4819 5785 6734 7668 8594]...
# Đã tách được 45 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 28576 samples
# Đã tính Hilbert envelope cho 28576 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8779
# Tìm thấy 30 peaks.
# Vị trí S1 (samples): [ 638 1643 2650 3660 4651 5696 6723 7729 8732 9720]...
# Đã tách được 29 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 29984 samples
# Đã tính Hilbert envelope cho 29984 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9273
# Tìm thấy 25 peaks.
# Vị trí S1 (samples): [ 731 1732 2723 3742 4777 5833 6860 7882 8892 9912]...
# Đã tách được 24 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 39392 samples
# Đã tính Hilbert envelope cho 39392 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9879
# Tìm thấy 13 peaks.
# Vị trí S1 (samples): [ 4125  5158 12775 13595 14572 24410 29929 32856 34001 34346]...
# Đã tách được 12 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 40576 samples
# Đã tính Hilbert envelope cho 40576 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9789
# Tìm thấy 28 peaks.
# Vị trí S1 (samples): [  419  4596  5675  6063  7021  8191  9351  9919 10484 11619]...
# Đã tách được 27 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 38784 samples
# Đã tính Hilbert envelope cho 38784 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0827
# Tìm thấy 21 peaks.
# Vị trí S1 (samples): [ 4885  5873  9725 10122 11602 12791 13504 13940 14434 14872]...
# Đã tách được 20 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 40192 samples
# Đã tính Hilbert envelope cho 40192 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0000
# Tìm thấy 68 peaks.
# Vị trí S1 (samples): [ 377  912 1385 1910 2378 2929 3918 4363 4918 5390]...
# Đã tách được 67 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 37696 samples
# Đã tính Hilbert envelope cho 37696 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.4313
# Tìm thấy 1 peaks.
# Vị trí S1 (samples): [460]...
# Không đủ S1 để tạo chu kỳ (chỉ có 1 S1)
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 39392 samples
# Đã tính Hilbert envelope cho 39392 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1067
# Tìm thấy 44 peaks.
# Vị trí S1 (samples): [ 905 1911 2968 3934 4931 5909 7090 7896 8836 9783]...
# Đã tách được 43 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 43584 samples
# Đã tính Hilbert envelope cho 43584 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9980
# Tìm thấy 21 peaks.
# Vị trí S1 (samples): [  818  3451  4153  5711  6798  7947  9128 10201 12031 13206]...
# Đã tách được 20 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 49504 samples
# Đã tính Hilbert envelope cho 49504 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1257
# Tìm thấy 47 peaks.
# Vị trí S1 (samples): [ 2898  3893  4918  5982  7058  9701 11213 12282 12755 13781]...
# Đã tách được 46 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 64192 samples
# Đã tính Hilbert envelope cho 64192 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0509
# Tìm thấy 85 peaks.
# Vị trí S1 (samples): [1062 2205 3778 4393 4874 5514 6168 6594 7103 8202]...
# Đã tách được 84 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 34560 samples
# Đã tính Hilbert envelope cho 34560 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.3297
# Tìm thấy 5 peaks.
# Vị trí S1 (samples): [22399 23968 25694 26286 33910]...
# Đã tách được 4 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 35104 samples
# Đã tính Hilbert envelope cho 35104 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9296
# Tìm thấy 44 peaks.
# Vị trí S1 (samples): [ 381 1291 2209 3159 4093 4984 5890 6858 7306 7797]...
# Đã tách được 43 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 41568 samples
# Đã tính Hilbert envelope cho 41568 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0143
# Tìm thấy 21 peaks.
# Vị trí S1 (samples): [   97  1563  1968  2487  3429  4377  5330  7208  8131 10004]...
# Đã tách được 20 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 47008 samples
# Đã tính Hilbert envelope cho 47008 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0089
# Tìm thấy 42 peaks.
# Vị trí S1 (samples): [  48  707 1413 1758 2203 2662 3125 3574 4028 6738]...
# Đã tách được 41 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 41312 samples
# Đã tính Hilbert envelope cho 41312 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1393
# Tìm thấy 36 peaks.
# Vị trí S1 (samples): [13072 14755 18106 18541 19270 20342 20683 21416 22696 23251]...
# Đã tách được 35 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 60096 samples
# Đã tính Hilbert envelope cho 60096 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.2524
# Tìm thấy 56 peaks.
# Vị trí S1 (samples): [ 328  951 1850 2748 3669 4602 5512 6432 8280 9189]...
# Đã tách được 55 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 46304 samples
# Đã tính Hilbert envelope cho 46304 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8054
# Tìm thấy 10 peaks.
# Vị trí S1 (samples): [  320   684  9160  9824 21644 26198 36027 38693 41800 46148]...
# Đã tách được 9 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 38784 samples
# Đã tính Hilbert envelope cho 38784 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8517
# Tìm thấy 12 peaks.
# Vị trí S1 (samples): [  100  1011  2615 25081 26383 26883 27192 27975 33346 34279]...
# Đã tách được 11 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 39776 samples
# Đã tính Hilbert envelope cho 39776 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.7032
# Tìm thấy 15 peaks.
# Vị trí S1 (samples): [  234   794  6636 22213 27208 28050 30238 30984 32757 35024]...
# Đã tách được 14 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 41504 samples
# Đã tính Hilbert envelope cho 41504 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9527
# Tìm thấy 25 peaks.
# Vị trí S1 (samples): [   69  3620  4611  8547  9506 10478 12459 13454 14420 15350]...
# Đã tách được 24 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 40000 samples
# Đã tính Hilbert envelope cho 40000 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8772
# Tìm thấy 70 peaks.
# Vị trí S1 (samples): [1878 2894 3886 4314 4882 5314 5894 6318 6908 7327]...
# Đã tách được 69 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 38528 samples
# Đã tính Hilbert envelope cho 38528 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9638
# Tìm thấy 36 peaks.
# Vị trí S1 (samples): [ 1979  5146  6248  7523  9526 10612 11698 13826 14880 15938]...
# Đã tách được 35 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 40512 samples
# Đã tính Hilbert envelope cho 40512 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1941
# Tìm thấy 42 peaks.
# Vị trí S1 (samples): [ 103 1120 1605 2195 2640 3192 4187 5187 6194 7182]...
# Đã tách được 41 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 42976 samples
# Đã tính Hilbert envelope cho 42976 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1610
# Tìm thấy 75 peaks.
# Vị trí S1 (samples): [ 513 1074 1547 2118 2584 3629 4190 4700 5277 5759]...
# Đã tách được 74 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 39488 samples
# Đã tính Hilbert envelope cho 39488 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0976
# Tìm thấy 38 peaks.
# Vị trí S1 (samples): [  545  1727  2811  3887  4982  6128  7211  8276  9352 10467]...
# Đã tách được 37 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 39392 samples
# Đã tính Hilbert envelope cho 39392 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9005
# Tìm thấy 34 peaks.
# Vị trí S1 (samples): [  304  1805  3383  4705  6080  7664  8628  9198 10549 12099]...
# Đã tách được 33 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 39968 samples
# Đã tính Hilbert envelope cho 39968 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.8507
# Tìm thấy 49 peaks.
# Vị trí S1 (samples): [  197  1490  2333  4050  5355  6461  6984  8301  9627 10370]...
# Đã tách được 48 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 40992 samples
# Đã tính Hilbert envelope cho 40992 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9353
# Tìm thấy 36 peaks.
# Vị trí S1 (samples): [ 2579  5166  6438  6826  8983  9618 10166 11089 13094 13862]...
# Đã tách được 35 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 39328 samples
# Đã tính Hilbert envelope cho 39328 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9480
# Tìm thấy 55 peaks.
# Vị trí S1 (samples): [ 128  684 1519 2074 2912 3483 4388 4925 5619 6181]...
# Đã tách được 54 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 37408 samples
# Đã tính Hilbert envelope cho 37408 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9366
# Tìm thấy 17 peaks.
# Vị trí S1 (samples): [ 2905  3891  4756  5183  5714  6634  7122  7617  8666 10835]...
# Đã tách được 16 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 39296 samples
# Đã tính Hilbert envelope cho 39296 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1238
# Tìm thấy 37 peaks.
# Vị trí S1 (samples): [  739  1683  3587  5362  6250  7247  8513  9025  9690 10909]...
# Đã tách được 36 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 55904 samples
# Đã tính Hilbert envelope cho 55904 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1219
# Tìm thấy 31 peaks.
# Vị trí S1 (samples): [  422  1959  7052  8328 11660 16949 18765 21339 25858 26380]...
# Đã tách được 30 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 39488 samples
# Đã tính Hilbert envelope cho 39488 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1681
# Tìm thấy 40 peaks.
# Vị trí S1 (samples): [ 891 1824 2769 3700 4649 5613 6486 7467 8403 9319]...
# Đã tách được 39 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 27392 samples
# Đã tính Hilbert envelope cho 27392 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.7407
# Tìm thấy 15 peaks.
# Vị trí S1 (samples): [ 1083  3209  4330  5459  7792 10228 12939 13967 15018 16093]...
# Đã tách được 14 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 36512 samples
# Đã tính Hilbert envelope cho 36512 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.4420
# Tìm thấy 3 peaks.
# Vị trí S1 (samples): [ 1966 35089 36341]...
# Đã tách được 2 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 39680 samples
# Đã tính Hilbert envelope cho 39680 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9790
# Tìm thấy 28 peaks.
# Vị trí S1 (samples): [ 4495  6197  6765 11207 13214 16358 17417 18005 18991 19563]...
# Đã tách được 27 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 39712 samples
# Đã tính Hilbert envelope cho 39712 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1042
# Tìm thấy 19 peaks.
# Vị trí S1 (samples): [ 2382  5531  7146 10229 11818 16389 17862 20846 22949 23854]...
# Đã tách được 18 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 39296 samples
# Đã tính Hilbert envelope cho 39296 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 1.9198
# Tìm thấy 23 peaks.
# Vị trí S1 (samples): [ 392  999 1929 2420 2737 3763 5175 6612 8116 9618]...
# Đã tách được 22 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 36320 samples
# Đã tính Hilbert envelope cho 36320 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0876
# Tìm thấy 13 peaks.
# Vị trí S1 (samples): [  745 18767 19512 24166 24801 28389 31073 32391 33044 33899]...
# Đã tách được 12 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 42304 samples
# Đã tính Hilbert envelope cho 42304 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.0626
# Tìm thấy 28 peaks.
# Vị trí S1 (samples): [  660  1568  2782  7024  9857 11969 13774 14533 15138 17051]...
# Đã tách được 27 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 40512 samples
# Đã tính Hilbert envelope cho 40512 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1403
# Tìm thấy 27 peaks.
# Vị trí S1 (samples): [ 552 1850 2796 3184 4474 5430 5774 7051 8310 9596]...
# Đã tách được 26 chu kỳ tim bằng Hilbert Transform
# Bắt đầu phân đoạn chu kỳ tim bằng Hilbert Transform cho tín hiệu 45792 samples
# Đã tính Hilbert envelope cho 45792 samples
# Đã làm mượt envelope với cửa sổ 161 samples
# Ngưỡng prominence thích ứng được tính: 2.1316
# Tìm thấy 35 peaks.
# Vị trí S1 (samples): [ 1269  2522  3758  5010  6219  7463  8696  9908 11123 12336]...
# Đã tách được 34 chu kỳ tim bằng Hilbert Transform
#
# Hoàn tất thu thập chu kỳ thô:
# - Đã xử lý thành công: 3007 file
# - Lỗi: 0 file
# - Tổng số chu kỳ thu thập được: 96877
# - Độ dài chu kỳ trung bình: 1360.18 samples
# - Phạm vi độ dài: 300 - 105620 samples

# %%
# ===== GIAI ĐOẠN 2: LỌC CHU KỲ THEO PHÂN VỊ P10–P90 =====
import numpy as np

# Tính phân vị P10 và P90 của độ dài chu kỳ
p10 = np.percentile(initial_durations_flat, 10)
p90 = np.percentile(initial_durations_flat, 90)

print(f"\nLọc chu kỳ theo độ dài từ P10 ({p10:.2f} samples) đến P90 ({p90:.2f} samples)")

# Lọc và lưu kết quả
filtered_cycles_flat = []
filtered_durations_flat = []
all_labels = []
all_patient_ids = []

for item in all_raw_cycles_info:
    cycle = item['cycle']
    duration = len(cycle)
    
    if p10 <= duration <= p90:
        filtered_cycles_flat.append(cycle)
        filtered_durations_flat.append(duration)
        all_labels.append(item['label'])
        all_patient_ids.append(item['patient_id'])

# %%
# In thống kê xử lý
print("--- Thống kê quá trình xử lý chu kỳ tim ---")
print(f"Tổng số file .wav đã đọc: {len(file_pairs)}")
print(f"Tổng số chu kỳ tim trước khi lọc: {len(initial_durations_flat)}")
print(f"Tổng số chu kỳ tim sau khi lọc và chuẩn hóa: {len(filtered_durations_flat)}")

if initial_durations_flat:
    print(f"Tỷ lệ chu kỳ được giữ lại: {len(filtered_durations_flat) / len(initial_durations_flat) if len(initial_durations_flat) > 0 else 0:.2%}")

if filtered_durations_flat:
    print(f"Độ dài trung bình của chu kỳ (trước lọc): {np.mean(initial_durations_flat):.2f} samples")
    print(f"Độ dài trung bình của chu kỳ (sau lọc): {np.mean(filtered_durations_flat):.2f} samples")
    
    # Thống kê phân bố theo lớp Present/Absent
    print("\n--- Phân bố chu kỳ theo lớp ---")
    unique_labels, counts = np.unique(all_labels, return_counts=True)
    for label, count in zip(unique_labels, counts):
        percentage = (count / len(all_labels)) * 100
        label_name = "Present" if label == 1 else "Absent"
        print(f"Lớp {label_name}: {count:,} chu kỳ ({percentage:.2f}%)")
    
    # Thống kê chi tiết hơn
    present_count = sum(1 for label in all_labels if label == 1)
    absent_count = sum(1 for label in all_labels if label == 0)
    total_cycles = len(all_labels)
    
    print(f"\nTổng kết:")
    print(f"- Chu kỳ có Murmur (Present): {present_count:,} ({present_count/total_cycles*100:.2f}%)")
    print(f"- Chu kỳ không có Murmur (Absent): {absent_count:,} ({absent_count/total_cycles*100:.2f}%)")
    print(f"- Tỷ lệ Present/Absent: 1:{absent_count/present_count:.2f}")
    
else:
    print("Không có chu kỳ nào được xử lý để tính toán độ dài.")
# Out:
# --- Thống kê quá trình xử lý chu kỳ tim ---
# Tổng số file .wav đã đọc: 2
# Tổng số chu kỳ tim trước khi lọc: 96877
# Tổng số chu kỳ tim sau khi lọc và chuẩn hóa: 77637
# Tỷ lệ chu kỳ được giữ lại: 80.14%
# Độ dài trung bình của chu kỳ (trước lọc): 1360.18 samples
# Độ dài trung bình của chu kỳ (sau lọc): 940.45 samples
#
# --- Phân bố chu kỳ theo lớp ---
# Lớp Absent: 60,994 chu kỳ (78.56%)
# Lớp Present: 16,643 chu kỳ (21.44%)
#
# Tổng kết:
# - Chu kỳ có Murmur (Present): 16,643 (21.44%)
# - Chu kỳ không có Murmur (Absent): 60,994 (78.56%)
# - Tỷ lệ Present/Absent: 1:3.66

# %%
def pad_or_crop(cycle, target_len=1600):
    if len(cycle) > target_len:
        # Nếu chu kỳ quá dài → cắt ở giữa
        start = (len(cycle) - target_len) // 2
        return cycle[start:start + target_len]
    
    elif len(cycle) < target_len:
        # Nếu chu kỳ quá ngắn → đệm thêm 0 ở cuối
        pad_width = target_len - len(cycle)
        return np.pad(cycle, (0, pad_width), mode='constant')
    
    # Nếu vừa đủ thì không làm gì
    return cycle

# Chuẩn hóa tất cả chu kỳ về cùng độ dài
X_cycles = np.array([pad_or_crop(cycle) for cycle in filtered_cycles_flat])

# %%
# 4.5. Cân bằng dữ liệu bằng Undersampling
# Giảm lớp Absent xuống 10k để cân bằng với Present

print("\n--- Cân bằng dữ liệu bằng Undersampling ---")
print(f"Trước cân bằng: Present={len([l for l in all_labels if l == 1])}, Absent={len([l for l in all_labels if l == 0])}")

# Tách dữ liệu theo lớp
present_indices = [i for i, label in enumerate(all_labels) if label == 1]
absent_indices = [i for i, label in enumerate(all_labels) if label == 0]

# Random sampling để lấy 10k mẫu Absent
import random
random.seed(42)  # Để kết quả có thể tái tạo
sampled_absent_indices = random.sample(absent_indices, 16000)

# Kết hợp indices
balanced_indices = present_indices + sampled_absent_indices
random.shuffle(balanced_indices)  # Trộn lại

# Tạo dữ liệu cân bằng
X_cycles_balanced = X_cycles[balanced_indices]
all_labels_balanced = [all_labels[i] for i in balanced_indices]
all_patient_ids_balanced = [all_patient_ids[i] for i in balanced_indices]

print(f"Sau cân bằng: Present={len([l for l in all_labels_balanced if l == 1])}, Absent={len([l for l in all_labels_balanced if l == 0])}")
print(f"Tổng số mẫu sau cân bằng: {len(all_labels_balanced)}")
print(f"Tỷ lệ Present/Absent mới: 1:{len([l for l in all_labels_balanced if l == 0])/len([l for l in all_labels_balanced if l == 1]):.2f}")

# Cập nhật biến để sử dụng cho các bước tiếp theo
X_cycles = X_cycles_balanced
y_labels = np.array(all_labels_balanced)
patient_ids_array = np.array(all_patient_ids_balanced)
# Out:
# --- Cân bằng dữ liệu bằng Undersampling ---
# Trước cân bằng: Present=16643, Absent=60994
# Sau cân bằng: Present=16643, Absent=16000
# Tổng số mẫu sau cân bằng: 32643
# Tỷ lệ Present/Absent mới: 1:0.96

# %%
# 5. Trích xuất Đặc trưng Scattering
# Khởi tạo Scattering Transform
if X_cycles.shape[0] > 0:
    print(f"Bắt đầu trích xuất đặc trưng scattering cho {X_cycles.shape[0]} chu kỳ...")
    scattering_transform = create_scattering_transform(J=J_SCATTER, Q=Q_SCATTER, shape=TARGET_CYCLE_LEN)

    # Trích xuất và chuẩn hóa đặc trưng
    start_scatter_time = time.time()
    X_scattering, feature_scaler = extract_and_scale_scattering_features(X_cycles, scattering_transform)
    end_scatter_time = time.time()

    print(f"Hoàn thành trích xuất đặc trưng trong {end_scatter_time - start_scatter_time:.2f} giây.")
    print(f"Kích thước của ma trận đặc trưng: {X_scattering.shape}")
else:
    print("Không có dữ liệu chu kỳ để trích xuất đặc trưng.")
    X_scattering = np.array([])
# Out:
# Bắt đầu trích xuất đặc trưng scattering cho 32643 chu kỳ...
# Hoàn thành trích xuất đặc trưng trong 127.15 giây.
# Kích thước của ma trận đặc trưng: (32643, 3200)

# %%
# 6. Chia dữ liệu thành các tập train, validation, và test
if X_scattering.shape[0] > 0:
    print("Bắt đầu chia dữ liệu cân bằng theo bệnh nhân (70/15/15)...")
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = split_and_save_dataset(
        X=X_scattering,
        y=y_labels,
        patient_ids=patient_ids_array,
        output_dir=PROCESSED_DATA_DIR,
        test_size=0.15,
        val_size=0.15
    )

    # In thống kê kích thước các tập
    print("\n--- Thống kê kích thước các tập dữ liệu cân bằng ---")
    print(f"Tập Train: {X_train.shape[0]} mẫu ({y_train.sum()} Murmur, {len(y_train) - y_train.sum()} Normal)")
    print(f"Tập Validation: {X_val.shape[0]} mẫu ({y_val.sum()} Murmur, {len(y_val) - y_val.sum()} Normal)")
    print(f"Tập Test: {X_test.shape[0]} mẫu ({y_test.sum()} Murmur, {len(y_test) - y_test.sum()} Normal)")
    
    # Tính tỷ lệ cân bằng trong từng tập
    print(f"\nTỷ lệ Present/Absent trong từng tập:")
    print(f"- Train: 1:{(len(y_train) - y_train.sum())/y_train.sum():.2f}")
    print(f"- Validation: 1:{(len(y_val) - y_val.sum())/y_val.sum():.2f}")
    print(f"- Test: 1:{(len(y_test) - y_test.sum())/y_test.sum():.2f}")
    print("--------------------------------------------")
else:
    print("Không có dữ liệu để chia.")
# Out:
# Bắt đầu chia dữ liệu cân bằng theo bệnh nhân (70/15/15)...
# Đã lưu các tập dữ liệu vào ../data/processed/
#
# --- Thống kê kích thước các tập dữ liệu cân bằng ---
# Tập Train: 23184 mẫu (11885 Murmur, 11299 Normal)
# Tập Validation: 4679 mẫu (2191 Murmur, 2488 Normal)
# Tập Test: 4780 mẫu (2567 Murmur, 2213 Normal)
#
# Tỷ lệ Present/Absent trong từng tập:
# - Train: 1:0.95
# - Validation: 1:1.14
# - Test: 1:0.86
# --------------------------------------------

# %%
# Lưu toàn bộ đặc trưng và nhãn cân bằng để có thể sử dụng lại nếu cần
if X_scattering.shape[0] > 0:
    full_features_path = os.path.join(PROCESSED_DATA_DIR, 'X_scattering_balanced.npz')
    full_labels_path = os.path.join(PROCESSED_DATA_DIR, 'y_labels_balanced.npy')

    np.savez_compressed(full_features_path, features=X_scattering)
    np.save(full_labels_path, y_labels)

    print(f"Đã lưu toàn bộ {X_scattering.shape[0]} đặc trưng cân bằng vào: {full_features_path}")
    print(f"Đã lưu toàn bộ {y_labels.shape[0]} nhãn cân bằng vào: {full_labels_path}")
    
    # Thống kê cuối cùng
    present_final = sum(y_labels)
    absent_final = len(y_labels) - present_final
    print(f"\n--- Thống kê cuối cùng sau cân bằng ---")
    print(f"Present: {present_final:,} ({present_final/len(y_labels)*100:.1f}%)")
    print(f"Absent: {absent_final:,} ({absent_final/len(y_labels)*100:.1f}%)")
    print(f"Tỷ lệ Present/Absent: 1:{absent_final/present_final:.2f}")
else:
    print("Không có dữ liệu để lưu.")
# Out:
# Đã lưu toàn bộ 32643 đặc trưng cân bằng vào: ../data/processed/X_scattering_balanced.npz
# Đã lưu toàn bộ 32643 nhãn cân bằng vào: ../data/processed/y_labels_balanced.npy
#
# --- Thống kê cuối cùng sau cân bằng ---
# Present: 16,643 (51.0%)
# Absent: 16,000 (49.0%)
# Tỷ lệ Present/Absent: 1:0.96
